# %%
import os
from dotenv import load_dotenv
load_dotenv()

REDIS_AM_HOST=os.environ.get('REDIS_AM_HOST')
REDIS_AM_API_KEY=os.environ.get('REDIS_AM_API_KEY')

# %%
import time
from redis_agent_memory import AgentMemory, models
