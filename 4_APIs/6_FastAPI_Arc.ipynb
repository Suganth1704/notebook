# %%
'''
High-level FastAPI architecture

                 Client
                   │
                   │ HTTP Request
                   ▼
          ┌──────────────────┐
          │   Uvicorn/ASGI   │
          │     Server       │
          └────────┬─────────┘
                   │
                   ▼
          ┌──────────────────┐
          │    Middleware    │
          │ Auth / Logging / │
          │ CORS / Errors    │
          └────────┬─────────┘
                   │
                   ▼
          ┌──────────────────┐
          │     Router       │
          │ /users /orders   │
          └────────┬─────────┘
                   │
                   ▼
          ┌──────────────────┐
          │ Endpoint/Service │
          │ Business Logic   │
          └────────┬─────────┘
                   │
          ┌────────┴─────────┐
          ▼                  ▼
   ┌──────────────┐   ┌──────────────┐
   │  Database    │   │ External API │
   │ PostgreSQL   │   │ / LLM / MCP  │
   └──────────────┘   └──────────────┘
                   │
                   ▼
          ┌──────────────────┐
          │ Pydantic Schema  │
          │ Validation/      │
          │ Serialization    │
          └────────┬─────────┘
                   │
                   ▼
               Response
'''

# %%
"""
ASGI = Asynchronous Server Gateway Interface

- It is a standard interface between a Python web server and a Python web application/framework
- Think of it as a contract that tell the server and application how to communicate

ASGI is the standard interface that allows an ASGI server such as Uvicorn to communicate with 
asynchronous Python web applications such as FastAPI, supporting async I/O and protocols such as HTTP 
and WebSockets.
"""
# Out:
# '\nASGI = Asynchronous Server Gateway Interface\n\n- It is a standard interface between a Python web server and a Python web application/framework\n- Think of it as a contract that tell the server and application how to communicate\n\nASGI is the standard interface that allows an ASGI server such as Uvicorn to communicate with \nasynchronous Python web applications such as FastAPI, supporting async I/O and protocols such as HTTP \nand WebSockets.\n'
