# %%
import os
from dotenv import load_dotenv
load_dotenv()

##llm
from langchain_groq import ChatGroq
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
llm = ChatGroq(model="openai/gpt-oss-120b")
# Out:
# d:\python\AI\pynb\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.4) doesn't match a supported version!
#   warnings.warn(
# d:\python\AI\pynb\.venv\Lib\site-packages\langchain_core\utils\pydantic.py:42: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1 import BaseModel as BaseModelV1

# %%
#from langchain_core.prompts import PromptTemplate

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant"),
        ("human", "Expalin {topic} simply.")
    ]
)

prompt.invoke({"topic":"What is python?"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content='You are a helpful assistant', additional_kwargs={}, response_metadata={}), HumanMessage(content='Expalin What is python? simply.', additional_kwargs={}, response_metadata={})])

# %%
from langchain_core.output_parsers import StrOutputParser
from pydantic import BaseModel

parser = StrOutputParser()

chain = prompt | llm | parser

# %%
result = chain.invoke({
    "topic": "Python decorators"
})

# %%
print(result)
# Out:
# **Python decorators in a nutshell**
#
# A *decorator* is a way to “wrap” a function (or a method, or even a class) with extra behavior, without changing the function’s own code.
# Think of it like putting a gift inside a box: the box adds something (wrapping paper, a ribbon) but the gift inside stays the same.
#
# ---
#
# ## 1. The basic idea
#
# ```python
# def my_decorator(func):
#     def wrapper(*args, **kwargs):
#         # code that runs *before* the original function
#         print("Before the function")
#
#         # call the original function
#         result = func(*args, **kwargs)
#
#         # code that runs *after* the original function
#         print("After the function")
#         return result
#     return wrapper
# ```
#
# - `my_decorator` receives a function (`func`) as an argument.
# - Inside it we define `wrapper`, which does something **before** and **after** calling `func`.
# - `my_decorator` returns the `wrapper` function, which replaces the original one.
#
# ---
#
# ## 2. Applying a decorator
#
# ### Without the `@` syntax
#
# ```python
# def greet(name):
#     print(f"Hello, {name}!")
#
# # Manually wrap it
# greet = my_decorator(greet)
#
# greet("Alice")
# ```
#
# Output:
#
# ```
# Before the function
# Hello, Alice!
# After the function
# ```
#
# ### With the `@` syntax (the common way)
#
# ```python
# @my_decorator          # <- this line applies the decorator
# def greet(name):
#     print(f"Hello, {name}!")
#
# greet("Bob")
# ```
#
# The `@my_decorator` line is just syntactic sugar for the manual assignment shown earlier.
#
# ---
#
# ## 3. Why use decorators?
#
# - **Reuse**: Write the “extra” logic once and apply it to many functions.
# - **Separation of concerns**: Keep the core function focused on its main job, while the decorator handles cross‑cutting concerns (logging, timing, authentication, caching, etc.).
# - **Readability**: The `@` line clearly signals that the function has been augmented.
#
# ---
#
# ## 4. Common built‑in decorators
#
# | Decorator | What it does |
# |-----------|--------------|
# | `@staticmethod` | Turns a method into a plain function that doesn’t receive `self` or `cls`. |
# | `@classmethod`  | Passes the class (`cls`) as the first argument instead of an instance. |
# | `@property`    | Lets you access a method like an attribute (read‑only by default). |
# | `@functools.lru_cache(maxsize=…)` | Caches results of a pure function to speed up repeated calls. |
# | `@dataclass` (from `dataclasses`) | Generates `__init__`, `__repr__`, etc., for a class automatically. |
#
# ---
#
# ## 5. A practical example: timing a function
#
# ```python
# import time
# from functools import wraps   # helps preserve metadata (name, docstring)
#
# def timer(func):
#     @wraps(func)               # keep func's __name__ and __doc__
#     def wrapper(*args, **kwargs):
#         start = time.perf_counter()
#         result = func(*args, **kwargs)
#         elapsed = time.perf_counter() - start
#         print(f"{func.__name__!r} took {elapsed:.4f}s")
#         return result
#     return wrapper
#
# @timer
# def slow_add(a, b):
#     """Adds two numbers after a short pause."""
#     time.sleep(0.7)
#     return a + b
#
# print(slow_add(3, 4))
# ```
#
# Output (approx.):
#
# ```
# 'slow_add' took 0.7021s
# 7
# ```
#
# The `timer` decorator adds timing logic without touching the original `slow_add` implementation.
#
# ---
#
# ## 6. Decorating functions with arguments
#
# If the decorator itself needs parameters (e.g., “log at this level”), you add another layer:
#
# ```python
# def repeat(times):
#     def decorator(func):
#         @wraps(func)
#         def wrapper(*args, **kwargs):
#             for _ in range(times):
#                 func(*args, **kwargs)
#         return wrapper
#     return decorator
#
# @repeat(3)               # will call hello() three times
# def hello():
#     print("Hi!")
#
# hello()
# ```
#
# Output:
#
# ```
# Hi!
# Hi!
# Hi!
# ```
#
# Here `repeat(3)` returns the actual decorator, which then receives `hello`.
#
# ---
#
# ## 7. Quick checklist when writing a decorator
#
# 1. **Accept any arguments**: use `*args, **kwargs` in the wrapper.
# 2. **Return the original result** (unless you intentionally want to change it).
# 3. **Preserve metadata**: add `@functools.wraps(func)` to the wrapper.
# 4. **Return the wrapper** from the outer function.
#
# ---
#
# ### TL;DR
#
# - A decorator is a function that takes another function and returns a new function that adds extra behavior.
# - Use `@decorator_name` above a function definition to apply it.
# - Great for logging, timing, access control, caching, and many other reusable patterns.

# %%
"""
Runnable sequence

chain = prompt | llm | parser
"""
# Out:
# '\nRunnable sequence\n\nchain = prompt | llm | parser\n'

# %%
structured_llm = llm.with_structured_output(Ouput)

chain = prompt | llm | parser
s_chain = prompt | llm

# %%
from langchain_core.runnables import RunnableParallel

runnable_chain = RunnableParallel(
    chain=chain,
    s_chain=s_chain
)

# %%
res=runnable_chain.invoke({"topic": "Python decorators"})
